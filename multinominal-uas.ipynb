# %% [markdown]
# <a href="https://www.kaggle.com/code/adhamal/multinominal-uas?scriptVersionId=100101879" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/uas-big/Emitten_Otomotive uas big data (3).csv

# %%
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('../input/uas-big/Emitten_Otomotive uas big data (3).csv')
df.head()
# Out:
#   Emitten          DER  Operating Profit Margin  Return On Asset  \
# 0    ACES  4694.129014               323.811134             0.39
# 1    BOGA   414.866513                 9.267144             0.78
# 2    CARS  3587.440084              -393.842268             7.75
# 3    CSAP  9917.317518               146.291316             2.89
# 4    DEPO   615.640776                45.051472             0.99
#
#    Sales Growth  Category
# 0          0.08         2
# 1          0.02         2
# 2         -0.11         2
# 3          0.02         2
# 4          0.09         2

# %%
np.asarray(df)
# Out:
# array([['ACES', 4694.129014098, 323.81113393, 0.39, 0.08, 2],
#        ['BOGA', 414.866513313, 9.267144214, 0.78, 0.02, 2],
#        ['CARS', 3587.440084355, -393.842267551, 7.75, -0.11, 2],
#        ['CSAP', 9917.317518, 146.291316, 2.89, 0.02, 2],
#        ['DEPO', 615.640776101, 45.051471753, 0.99, 0.09, 2],
#        ['ECII', 1274.602008118, -8.259235717, 0.39, -0.01, 4],
#        ['ERAA', 31180.63533, 799.292894, 0.8, 0.09, 2],
#        ['GLOB', 31.560498, 1.958517872, -1.02, -3.54, 2],
#        ['IMAS', 14054.799924092, -93.42833736, 2.9, 0.0, 2],
#        ['LPPF', 4084.782, 438.694, 4.46, 0.1, 2],
#        ['MAPA', 3799.881, -14.91, 0.8, 0.02, 2],
#        ['MAPI', 12080.468, -114.804, 1.61, -0.01, 2],
#        ['MKNT', 1535.265401908, -16.993162056, 9.36, -0.06, 2],
#        ['MPMX', 9566.418, 322.535, 0.56, 0.05, 2],
#        ['PMJS', 6702.167259202, 128.438921588, 0.41, 0.04, 2],
#        ['SLIS', 321.174361144, 20.02518215, 0.91, 0.06, 2],
# ...

# %%
import statsmodels.api as sm

# %%
df.drop(['Emitten'], axis=1, inplace=True)

# %%
x = df.drop('Category', axis=1)
x.head()
# Out:
#            DER  Operating Profit Margin  Return On Asset  Sales Growth
# 0  4694.129014               323.811134             0.39          0.08
# 1   414.866513                 9.267144             0.78          0.02
# 2  3587.440084              -393.842268             7.75         -0.11
# 3  9917.317518               146.291316             2.89          0.02
# 4   615.640776                45.051472             0.99          0.09

# %%
y = df['Category']
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Category, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train_sm = sm.add_constant(x_train)
x_train_sm
# Out:
#     const           DER  Operating Profit Margin  Return On Asset  \
# 5     1.0   1274.602008                -8.259236             0.39
# 20    1.0    516.334727                 8.044222             1.39
# 3     1.0   9917.317518               146.291316             2.89
# 2     1.0   3587.440084              -393.842268             7.75
# 7     1.0     31.560498                 1.958518            -1.02
# 0     1.0   4694.129014               323.811134             0.39
# 17    1.0   1102.337000               -83.311000            -1.06
# 13    1.0   9566.418000               322.535000             0.56
# 19    1.0   8643.623000               367.124000             0.51
# 21    1.0    318.034330                 6.914959             0.99
# 11    1.0  12080.468000              -114.804000             1.61
# 6     1.0  31180.635330               799.292894             0.80
# 12    1.0   1535.265402               -16.993162             9.36
# ...

# %%
#logit_mod = sm.Logit(y_train, x_train_sm
                     
mnlogit_mod = sm.MNLogit(y_train, x_train_sm)
mnlogit_fit = mnlogit_mod.fit()
# Out:
# ...
#          Current function value: nan
#          Iterations: 35
# /opt/conda/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py:2331: RuntimeWarning: divide by zero encountered in log
#   logprob = np.log(self.cdf(np.dot(self.exog,params)))
# /opt/conda/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py:2332: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(d * logprob)
# /opt/conda/lib/python3.7/site-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
print (mnlogit_fit.summary())
# Out:
#                           MNLogit Regression Results
# ...
# Dep. Variable:               Category   No. Observations:                   17
# Model:                        MNLogit   Df Residuals:                       12
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 05 Jul 2022   Pseudo R-squ.:                     nan
# Time:                        15:47:56   Log-Likelihood:                    nan
# converged:                      False   LL-Null:                       -3.8032
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#              Category=4       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      51.2005   1.23e+04      0.004      0.997    -2.4e+04    2.41e+04
# DER                        -0.0048      1.238     -0.004      0.997      -2.432       2.422
# ...

# %%
model = LogisticRegression(multi_class='ovr')
model.fit(x_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
model.predict_proba(x_test)[0:5]
# Out:
# array([[0.99815576, 0.00184424],
#        [0.82950456, 0.17049544],
#        [0.85164648, 0.14835352],
#        [0.7286645 , 0.2713355 ],
#        [0.82608755, 0.17391245]])

# %%
predictions = model.predict(x_test)
predictions
# Out:
# array([2, 2, 2, 2, 2])

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %%
print(accuracy_score(y_test, predictions))
# Out:
# 1.0
